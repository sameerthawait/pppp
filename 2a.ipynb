# %% [markdown]
# <a href="https://colab.research.google.com/github/sameerthawait/pppp/blob/main/2b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def binarySearch(arr, low, high, x):
    while low <= high:
        mid = low + (high - low) // 2

        if arr[mid] == x:
            return mid
        elif arr[mid] < x:
            low = mid + 1
        else:
            high = mid - 1

    return -1

n = int(input("Enter number of elements: "))
arr = list(map(int, input("Enter sorted array elements: ").split()))

x = int(input("Enter element to search: "))

result = binarySearch(arr, 0, n - 1, x)

if result != -1:
    print("Element is present at index", result)
else:
    print("Element is not present in array")
# Out:
# Enter number of elements: 5
# Enter sorted array elements:  1 4 6  8 9
# Enter element to search: 8
# Element is present at index 3
