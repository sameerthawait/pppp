# %% [markdown]
# <a href="https://colab.research.google.com/github/sameerthawait/pppp/blob/main/5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Edge:
    def __init__(self, u, v, w):
        self.u = u
        self.v = v
        self.w = w

# Input
V = int(input("Enter number of vertices: "))
E = int(input("Enter number of edges: "))

edges = []
print("Enter edges (u v w):")
for _ in range(E):
    u, v, w = map(int, input().split())
    edges.append(Edge(u, v, w))

source = int(input("Enter source vertex: "))

# Initialize distances
dist = [float('inf')] * V
dist[source] = 0

# Relax edges V-1 times
for _ in range(V - 1):
    for edge in edges:
        if dist[edge.u] != float('inf') and dist[edge.u] + edge.w < dist[edge.v]:
            dist[edge.v] = dist[edge.u] + edge.w

# Check negative weight cycle
for edge in edges:
    if dist[edge.u] != float('inf') and dist[edge.u] + edge.w < dist[edge.v]:
        print("Graph contains negative weight cycle")
        exit()

# Output
print("\nVertex\tDistance from Source")
for i in range(V):
    print(i, "\t", dist[i])
